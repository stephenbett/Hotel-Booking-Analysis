# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv('hotel_bookings.csv')
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 29.1+ MB

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# max                   53.000000                  31.000000
#
#        stays_in_weekend_nights  stays_in_week_nights         adults  \
# count            119390.000000         119390.000000  119390.000000
# mean                  0.927599              2.500302       1.856403
# std                   0.998613              1.908286       0.579261
# min                   0.000000              0.000000       0.000000
# 25%                   0.000000              1.000000       2.000000
# 50%                   1.000000              2.000000       2.000000
# 75%                   2.000000              3.000000       2.000000
# max                  19.000000             50.000000      55.000000
#
#             children         babies  is_repeated_guest  \
# count  119386.000000  119390.000000      119390.000000
# mean        0.103890       0.007949           0.031912
# std         0.398561       0.097436           0.175767
# min         0.000000       0.000000           0.000000
# 25%         0.000000       0.000000           0.000000
# 50%         0.000000       0.000000           0.000000
# 75%         0.000000       0.000000           0.000000
# max        10.000000      10.000000           1.000000
#
#        previous_cancellations  previous_bookings_not_canceled  \
# count           119390.000000                   119390.000000
# mean                 0.087118                        0.137097
# std                  0.844336                        1.497437
# min                  0.000000                        0.000000
# 25%                  0.000000                        0.000000
# 50%                  0.000000                        0.000000
# 75%                  0.000000                        0.000000
# max                 26.000000                       72.000000
#
#        booking_changes          agent      company  days_in_waiting_list  \
# count    119390.000000  103050.000000  6797.000000         119390.000000
# mean          0.221124      86.693382   189.266735              2.321149
# std           0.652306     110.774548   131.655015             17.594721
# min           0.000000       1.000000     6.000000              0.000000
# 25%           0.000000       9.000000    62.000000              0.000000
# 50%           0.000000      14.000000   179.000000              0.000000
# 75%           0.000000     229.000000   270.000000              0.000000
# max          21.000000     535.000000   543.000000            391.000000
#
#                  adr  required_car_parking_spaces  total_of_special_requests
# count  119390.000000                119390.000000              119390.000000
# mean      101.831122                     0.062518                   0.571363
# std        50.535790                     0.245291                   0.792798
# min        -6.380000                     0.000000                   0.000000
# 25%        69.290000                     0.000000                   0.000000
# 50%        94.575000                     0.000000                   0.000000
# 75%       126.000000                     0.000000                   1.000000
# max      5400.000000                     8.000000                   5.000000

# %%
data.shape
# Out:
# (119390, 32)

# %%
# data.drank

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
print(data['stays_in_weekend_nights'])
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 119385    2
# 119386    2
# 119387    2
# 119388    2
# 119389    2
# Name: stays_in_weekend_nights, Length: 119390, dtype: int64

# %%
time = data[['arrival_date_year','arrival_date_month','arrival_date_week_number','arrival_date_day_of_month','stays_in_weekend_nights']].copy()
time
# Out:
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# 1                    2015               July                        27
# 2                    2015               July                        27
# 3                    2015               July                        27
# 4                    2015               July                        27
# ...                   ...                ...                       ...
# 119385               2017             August                        35
# 119386               2017             August                        35
# 119387               2017             August                        35
# 119388               2017             August                        35
# 119389               2017             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights
# 0                               1                        0
# 1                               1                        0
# 2                               1                        0
# 3                               1                        0
# 4                               1                        0
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
# [119390 rows x 5 columns]

# %%
time.isnull().sum()
# Out:
# arrival_date_year            0
# arrival_date_month           0
# arrival_date_week_number     0
# arrival_date_day_of_month    0
# stays_in_weekend_nights      0
# dtype: int64

# %%
time['arrival_date_year']
# Out:
# 240708931

# %%
time['arrival_date_year'].mode()
# Out:
# 0    2016
# dtype: int64

# %%
time['arrival_date_month'].mode()
# Out:
# 0    August
# dtype: object

# %%
time['arrival_date_day_of_month'].mode()
# Out:
# 0    17
# dtype: int64

# %%
print('The number of Resort hotels is: ', data.hotel[data.hotel =='Resort Hotel'].count())
# Out:
# The number of Resort hotels is:  40060

# %%
print('The number of City hotels is: ', data.hotel[data.hotel =='City Hotel'].count())
# Out:
# The number of City hotels is:  79330

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# reservation_status_date                0
# dtype: int64

# %%
chef =data[['hotel','meal','country']].copy()
chef
# Out:
#                hotel meal country
# 0       Resort Hotel   BB     PRT
# 1       Resort Hotel   BB     PRT
# 2       Resort Hotel   BB     GBR
# 3       Resort Hotel   BB     GBR
# 4       Resort Hotel   BB     GBR
# ...              ...  ...     ...
# 119385    City Hotel   BB     BEL
# 119386    City Hotel   BB     FRA
# 119387    City Hotel   BB     DEU
# 119388    City Hotel   BB     GBR
# 119389    City Hotel   HB     DEU
#
# [119390 rows x 3 columns]

# %%
chef.isnull().sum()
# Out:
# hotel        0
# meal         0
# country    488
# dtype: int64

# %%
chef2 =chef.fillna(0.0)
chef2.isnull().sum()
# Out:
# hotel      0
# meal       0
# country    0
# dtype: int64

# %%
chef2.loc[:,['country']].head(30)
# Out:
#    country
# 0      PRT
# 1      PRT
# 2      GBR
# 3      GBR
# 4      GBR
# 5      GBR
# 6      PRT
# 7      PRT
# 8      PRT
# 9      PRT
# 10     PRT
# 11     PRT
# 12     USA
# 13     ESP
# 14     PRT
# 15     IRL
# 16     PRT
# 17     IRL
# 18     FRA
# 19     GBR
# 20     GBR
# 21     PRT
# 22     PRT
# 23     PRT
# 24     GBR
# 25     PRT
# 26     IRL
# 27     PRT
# 28     PRT
# 29     PRT

# %%
chef2['country'].mode()
# Out:
# 0    PRT
# dtype: object

# %%
chef2.head(20)
# Out:
#            hotel meal country
# 0   Resort Hotel   BB     PRT
# 1   Resort Hotel   BB     PRT
# 2   Resort Hotel   BB     GBR
# 3   Resort Hotel   BB     GBR
# 4   Resort Hotel   BB     GBR
# 5   Resort Hotel   BB     GBR
# 6   Resort Hotel   BB     PRT
# 7   Resort Hotel   FB     PRT
# 8   Resort Hotel   BB     PRT
# 9   Resort Hotel   HB     PRT
# 10  Resort Hotel   BB     PRT
# 11  Resort Hotel   HB     PRT
# 12  Resort Hotel   BB     USA
# 13  Resort Hotel   HB     ESP
# 14  Resort Hotel   BB     PRT
# 15  Resort Hotel   BB     IRL
# 16  Resort Hotel   BB     PRT
# 17  Resort Hotel   BB     IRL
# 18  Resort Hotel   BB     FRA
# 19  Resort Hotel   BB     GBR

# %%
# x =chef2.loc['country']
# y =chef2.loc['meal']
# fig = plt.figure()
# plt.xlabel('Countries')
# plt.ylabel('HOTEL TYPE')
# plt.pie (y, labels=x,autopct= '%1.2f%%')
# plt.title('Hotel data')
# plt.show ()
# 'ESP','IRL','FRA','GBR','PRT'

# %%
sns.set_style("darkgrid")
hotel_type =chef2['hotel'].value_counts()
plot =hotel_type.plot.pie( x ='City Hotel', y='Resort Hotel', autopct ='%1.1f%%', figsize =(8,8))
plot.title('HotelBooking in \n City HoteL and Resort Hotel')
plot.rcParams['font.size'] =20.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12848/2391163814.py in <module>
#       2 hotel_type =chef2['hotel'].value_counts()
#       3 plot =hotel_type.plot.pie( x ='City Hotel', y='Resort Hotel', autopct ='%1.1f%%', figsize =(8,8))
# ----> 4 plot.title('HotelBooking in \n City HoteL and Resort Hotel')
#       5 plot.rcParams['font.size'] =20.0
#
# TypeError: 'Text' object is not callable

# %%
 Resort =chef2['hotel'].where(chef2['hotel']=='Resort Hotel')
Resort
# chef2.loc[['Resort Hotel']
# Out:
# 0         Resort Hotel
# 1         Resort Hotel
# 2         Resort Hotel
# 3         Resort Hotel
# 4         Resort Hotel
#               ...
# 119385             NaN
# 119386             NaN
# 119387             NaN
# 119388             NaN
# 119389             NaN
# Name: hotel, Length: 119390, dtype: object

# %%
pip install pycountry
# Out:
# Collecting pycountryNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: setuptools in c:\users\bett\anaconda3\lib\site-packages (from pycountry) (58.0.4)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (PEP 517): started
#   Building wheel for pycountry (PEP 517): still running...
#   Building wheel for pycountry (PEP 517): finished with status 'done'
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681832 sha256=5d278866d2abe6c86dff307ca384ddf73b83e4145ce1e92fcb302b4a198baea4
#   Stored in directory: c:\users\bett\appdata\local\pip\cache\wheels\47\15\92\e6dc85fcb0686c82e1edbcfdf80cfe4808c058813fed0baa8f
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5

# %%
def get_count(series, limit=None):
    
    '''
    INPUT:
        series: Pandas Series (Single Column from DataFrame)
        limit:  If value given, limit the output value to first limit samples.
    OUTPUT:
        x = Unique values
        y = Count of unique values
    '''
    
    if limit != None:
        series = series.value_counts()[:limit]
    else:
        series = series.value_counts()
    
    x = series.index
    y = series/series.sum()*100
    
    return x.values,y.values

# %%
import pycountry as pc
x,y = get_count(df_not_canceled['country'], limit=10)

## For each country code select the country name 
country_name = [pc.countries.get(alpha_3=name).name for name in x]

plot(country_name,y, x_label='Countries', y_label='Total Booking (%)', title='country-wise comparison', figsize=(15,7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12848/3072223027.py in <module>
#       1 import pycountry as pc
# ----> 2 x,y = get_count(df_not_canceled['country'], limit=10)
#       3
#       4 ## For each country code select the country name
#       5 country_name = [pc.countries.get(alpha_3=name).name for name in x]
#
# NameError: name 'get_count' is not defined

# %%
total_nights =data['stays_in_weekend_nights']+ df_not_canceled['stays_in_week_nights']
x,y = get_count(total_nights, limit=10)

plot(x,y, x_label='Number of Nights', y_label='Booking Percentage (%)', title='Night Stay Duration (Top 10)', figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12848/2600589478.py in <module>
# ----> 1 total_nights = df_not_canceled['stays_in_weekend_nights']+ df_not_canceled['stays_in_week_nights']
#       2 x,y = get_count(total_nights, limit=10)
#       3
#       4 plot(x,y, x_label='Number of Nights', y_label='Booking Percentage (%)', title='Night Stay Duration (Top 10)', figsize=(10,5))
#
# NameError: name 'df_not_canceled' is not defined

# %%
plt.subplots(figsize=(7,5))
sns.countplot(x='arrival_date_year', hue='hotel',  data=df_not_canceled);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12848/2278687484.py in <module>
#       1 plt.subplots(figsize=(7,5))
# ----> 2 sns.countplot(x='arrival_date_year', hue='hotel',  data=df_not_canceled);
#
# NameError: name 'df_not_canceled' is not defined
